# %% [markdown]
# ## Journaling Instructions
#
# Maxwell Braseth
# 09/06/2026
# DS 5110: Data Engineering II: Big Data Systems
# Module 01
#
#
# The purpose of this exercise is to track your learning and growth through this course.
# You will add an entry for each Module (ideally on a weekly basis).
# You will submit your journal over the course of the term and it will grow with your new entries.
#
# Each entry should answer some or all of these questions:
# - What were some things you learned in the module?
#
# After completing Module 01, I would say that I learned a lot about the essential Data Engineering related functions, frameworks and concepts that keeps our data infrastructure around the internet running. In other words, Module 01 revealed to me all of the essential data related details to how our current day internet infrastructure runs in terms of the components of data processing and engineering. In particular, the essential four step process to our Big Data Systems (1. Data Ingestion, 2. Data Storage, 3. Data Processing, 4. Reporting and Visualization) revealed to me the essential way to best understand the core details of how most Big Data Systems actually needs to operate successfully.
#
# - What do you think were the most important concepts?
#
# In my opinion, the focal concept of this module was the MapReduce framework which describes the actual essential Data Engineering and Processing jobs/tasks that Big Data Systems platforms conduct. The MapReduce framework in particular revealed to me how Data Processing is conducted through a specific manipulation process of where inputted data files goes through several phases to create an output file with the reduced data based on the shared keys that the inputted data is assigned during those phases. Altogether, this framework allows Big Data Systems to best format the outputted data for later usage such as querying, conducting business analytics upon it and later consolidation of this data with other potential computer/information systems. The other important concepts of this module includes the descriptions of the Big Data System platforms of Spark and Hadoop that describes the architecture and functions of the most mainstream Data Processing platforms that most companies, organizations and individuals use in their personal and business operations. Finally, the conceptions of the top four types of Big Data features (1. Volume, 2. Velocity, 3. Variety, 4. Veracity) that these platforms need to successful complete their processes and services along with these features being the best indicators for determining the best downstream data performances for when this data is integrated into other applications (BI reports, business reports, Third-party applications (such as Google Maps)).
#
# - What was challenging for you? How can you learn it better?
#
# The most challenging detail of this module was fully understanding the MapReduce framework and how its infrastructure completely functions to create the output files that create the best Downstream Data performances. The whole infrastructure and its functions along with its fault tolerances and mechanisms for dealing with possible errors that occurs in these Data Processing operations is very complex where I took a lot of time to understand. Even at the end of the readings in this module, I was never truly able to fully understand all of its granular technical details and understand how certain processes required the usage of these Master and Worker programs along with determining why certain tasks/jobs occurred so successfully while others would fail along with determining how each phase had their own successful and failed status conditional parameters to finish their phase(s). The best solution I have to learn this framework better is to actually to first understand the essential process (step by step) that the MapReduce framework follows for successful Data Processing, then conduct this process myself and then experiment with this process to better understand the granular details and mechanisms to how this system truly functions.
#
# - Which parts did you enjoy?
#
# In conclusion, the best parts of this module was actually learning about the different types of data-related job(s)/task(s) that the Big Data Systems conducts to complete their Data Processing operations and how these different types of job(s)/task(s) are used for different purposes within the Big Data Systems. For example, the Streaming job(s)/task(s) from Hadoop are used to help this platform process the many instances of data chunks from various sources along with using these same task(s)/job(s) to conduct the essential web scaling and digital resource allocation across this distributed system to secure better downstream app and MapReduce operations. On top of those details, it was very interesting to learn about Batch job(s)/task(s) and how they are used by Spark to batch together smaller data chunks and blocked datasets to conduct essential computations for set predictions in the data along with performing essential aggregation calculations. The only other parts that I really enjoyed was about how the Spark Big Data Platform depends on Resilient Distributed Dataset (RDD) which serves as the Spark abstraction of data that is distributed across the platform for its operations and how it has particular properties to deal with many events that happens within the platform. For example, RDD has a series of dependencies that allows this type of data to be recreated if the RDD creation process were to fail and how this type of data uses a particular type of partition for splitting this type of data to store and distribute certain nodes in the clusters within this platform.
#
#
# Positive feedback is also fine (e.g., Exercise X, Part Y wasn't clear) but negative criticism should be avoided.
#
# Each entry should:
# - Use full sentences to show good writing and clear thought process
# - Be limited to one or two paragraphs (it should be fairly brief)
#
# File format: Use a Word doc or similar. Recycle the same file throughout the course.
